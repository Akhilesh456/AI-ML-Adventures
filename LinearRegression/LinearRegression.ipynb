# %%
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %% [markdown]
# Reading train data and plotting the data points.

# %%
train_data = pd.read_csv("train.csv")
X_train = train_data['x'].to_numpy()
Y_train = train_data['y'].to_numpy()
plt.scatter(X_train, Y_train, c='r', marker='x')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# Defining the cost function, and Gradient Descent algorithm.

# %%
def cost_func(x, y, w, b):
    """Computes the cost of the model F(w, b) for a choosen w and b

    Args:
        x (np.array): The inputs for the model
        y (np.array): The "Correct" outputs
        w (Number): w parameter
        b (Number): b parameter

    Returns:
        Number: The cost of the model.
    """
    m = len(x)
    s = 0
    for i in range(m):
        f_wb = w*x[i] + b
        s = s + (f_wb - y[i])**2
    total_cost = s/(2*m)
    return total_cost

def compute_gradient(x, y, w, b):
    """Computes the gradient of cost function at w and b

    Args:
        x (np.array): Training inputs
        y (np.array): Training oupts (Correct answers)
        w (Number): w parameter
        b (Number): b parameter

    Returns:
        Number, Number: dj_dw and dj_db
    """
    m = len(x)
    dj_dw = 0
    dj_db = 0
    
    for i in range(m):
        f_wb = w*x[i] + b
        er = (f_wb - y[i])
        dj_dw = dj_dw + er*x[i]
        dj_db = dj_db + er
    dj_dw = dj_dw/m
    dj_db = dj_db/m
    
    return dj_dw, dj_db

def GD_algorithm(x, y, alpha):
    """Calculates the best fit for the model f_w,b(X) = w*X + b for the given data and learning rate

    Args:
        x (np.array): Inputs of training data
        y (np.array): Correct key of output data
        alpha (Number): Learning Rate

    Returns:
        w, b, J_history: Parameters and Cost function history for Learning Curve
    """
    J_history = []
    w = 0
    b = 0
    prev_J = cost_func(x, y, w, b)
    iterations = 0
    while(True):
        iterations += 1
        dj_dw, dj_db = compute_gradient(x, y, w, b)
        w = w - alpha*dj_dw
        b = b - alpha*dj_db
        curr_J = cost_func(x, y, w, b)
        
        J_history.append(curr_J)
        # print(f"w: {w}, b: {b}, J: {curr_J}")
        if(curr_J > prev_J):
            print(f"The value of alpha: {alpha} is too large, try a smaller value.")
            break
        if(prev_J-curr_J < 0.000001):
            return w, b, J_history, iterations
        
        prev_J = curr_J


def predict(x, w, b):
    """Predicts the data based on the input parameters

    Args:
        x (np.array): Inputs
        w (Number): w parameter
        b (Number): b parameter

    Returns:
        np.array: Predictions
    """
    Y_pred = []   
    m = len(x)
    
    for i in range(m):
        Y_pred.append(w*x[i]+b)
        
    return Y_pred

# %% [markdown]
# Let's implement the Gradient Descent algorithm.

# %%
alpha = 0.0001
w, b, J_history, iterations = GD_algorithm(X_train, Y_train, alpha)

# Plotting Learning Curve
s = len(J_history)
indices = range(s)
plt.plot(indices, J_history, c='b')
plt.xlabel("# Iterations")
plt.ylabel("Cost Function")
plt.title("Learning Curve")
plt.show()

Y_test_pred = predict(X_train, w, b)

plt.plot(X_train, Y_test_pred, c='b')
plt.scatter(X_train, Y_train, c='r', marker='x')
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Linear Regerssion")
plt.show()

# %% [markdown]
# Let's test for the test data.

# %%
test_data = pd.read_csv("test.csv")
X_test = test_data['x'].to_numpy()
Y_test = test_data['y'].to_numpy()

Y_test_pred = predict(X_test, w, b)

print(f"Accuracy of the model is {r2_score(Y_test, Y_test_pred)}")
plt.scatter(X_test, Y_test, c='r', marker='x')
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(X_test, Y_test_pred, c='b')
plt.show()
# Out:
# Accuracy of the model is 0.9887665142377259
